# %%
from pymongo import MongoClient
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_pinecone import PineconeVectorStore
from pinecone import Pinecone, ServerlessSpec
from uuid import uuid4
from dotenv import load_dotenv
from langchain.schema import Document 
from langchain_huggingface import HuggingFaceEndpoint
import os
from langchain.schema.runnable import RunnablePassthrough
from langchain.schema.output_parser import StrOutputParser

# %% [markdown]
# ### Setting Up API Keys

# %%
# env_content = f"""
# HUGGINGFACE_API_KEY={HUGGINGFACE_API_KEY}
# PINECONE_API_KEY={PINECONE_API_KEY}
# """

# with open(".env", "w") as file:
#     file.write(env_content)

# print("Environment variables are saved to .env file.")
# Out:
# Environment variables are saved to .env file.

# %% [markdown]
# ### Loading the Environment File

# %%
import dotenv

dotenv.load_dotenv()

MONGODB_URI = os.getenv("MONGODB_URI")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
HUGGINGFACE_API_KEY = os.getenv("HUGGINGFACE_API_KEY")
PINECONE_API_KEY
# Out:
# 'pcsk_iAgUU_FXUSfemuBAKgQTBG1eKLxZyoxA9RfUMgdpQJNkF8H1dYSaQtRbRAauDzviDsQ8w'

# %% [markdown]
# ### MongoDB and Pinecone Setup for Embedding Storage and Querying ###
# Connecting to MongoDB and Pinecone, we check if a specified Pinecone index exists, and create it if not. We then initialize an embedding model using Hugging Face and set up a vector store with Pinecone for storing and querying product embeddings.

# %%
# Load environment variables from .env file
load_dotenv()

# MongoDB connection setup
MONGODB_URI = os.getenv("MONGODB_URI")

# Connect to MongoDB
try:
    client = MongoClient(MONGODB_URI)
    # Ping the database to check if the connection is successful
    client.admin.command('ping')
    print("Connected to MongoDB successfully!")
except Exception as e:
    print("Failed to connect to MongoDB:", e)
    exit(1)

# Select the database and collection
db = client["test"]
collection = db["productdata"]



# Pinecone connection
pc = Pinecone("pcsk_iAgUU_FXUSfemuBAKgQTBG1eKLxZyoxA9RfUMgdpQJNkF8H1dYSaQtRbRAauDzviDsQ8w")

# Define Pinecone index name
index_name = "llms-project"

# Check if index exists, else create it
if index_name not in pc.list_indexes().names():
    pc.create_index(
        name=index_name,
        dimension=768,
        metric="cosine",
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
        )
    )

# Initialize embedding model and vector store
embeddings = HuggingFaceEmbeddings()  # This should default to a model like "sentence-transformers/all-MiniLM-L6-v2"
index = pc.Index(index_name)
vector_store = PineconeVectorStore(index=index, embedding=embeddings)
# Out:
# Connected to MongoDB successfully!

# %% [markdown]
# ### Adding Product Embeddings to Pinecone and Updating MongoDB ###
# This code iterates through products in the MongoDB collection, checks if embeddings have already been created for each product, and processes only those without embeddings. It generates embeddings using a detailed product description, adds them to the Pinecone vector store with a unique ID, and updates MongoDB to mark the product as processed.

# %%
products = collection.find()

for product in products:

    if product:
        # Check if the "Embeddings Created" flag exists and is set to True
        detailed_description = product.get("detailed_description", "")
        
        if not detailed_description:
            print("Product does not have a detailed description.")
        else:
            # Create a Document with the necessary fields
            document = Document(
                page_content=detailed_description,
                metadata={
                    "mongo_id": str(product["_id"]),
                    "description": detailed_description
                }
            )

            # Generate unique ID for Pinecone
            unique_id = str(uuid4())

            # Add the document to Pinecone
            vector_store.add_documents(documents=[document], ids=[unique_id])

            # Update MongoDB to mark embeddings as created
            collection.update_one(
                {"_id": product["_id"]},
                {"$set": {"Embeddings Created": True}}
            )

            print(f"Product with MongoDB ID {product['_id']} added to Pinecone with embedding.")
    else:
         print("No product found in the database.")
# Out:
# Product with MongoDB ID 676a38ac63fe6ff887c1d633 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d634 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d635 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d636 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d637 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d638 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d639 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d63a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d63b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d63c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d63d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d63e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d63f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d640 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d641 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d642 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d643 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d644 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d645 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d646 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d647 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d648 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d649 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d64a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d64b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d64c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d64d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d64e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d64f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d650 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d651 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d652 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d653 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d654 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d655 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d656 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d657 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d658 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d659 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d65a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d65b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d65c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d65d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d65e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d65f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d660 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d661 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d662 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d663 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d664 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d665 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d666 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d667 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d668 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d669 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d66a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d66b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d66c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d66d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d66e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d66f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d670 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d671 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d672 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d673 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d674 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d675 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d676 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d677 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d678 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d679 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d67a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d67b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d67c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d67d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d67e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d67f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d680 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d681 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d682 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d683 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d684 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d685 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d686 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d687 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d688 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d689 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d68a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d68b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d68c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d68d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d68e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d68f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d690 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d691 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d692 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d693 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d694 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d695 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d696 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d697 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d698 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d699 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d69a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d69b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d69c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d69d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d69e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d69f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6a0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6a1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6a2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6a3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6a4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6a5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6a6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6a7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6a8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6a9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6aa added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6ab added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6ac added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6ad added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6ae added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6af added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6b0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6b1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6b2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6b3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6b4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6b5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6b6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6b7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6b8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6b9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6ba added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6bb added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6bc added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6bd added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6be added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6bf added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6c0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6c1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6c2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6c3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6c4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6c5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6c6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6c7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6c8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6c9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6ca added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6cb added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6cc added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6cd added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6ce added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6cf added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6d0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6d1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6d2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6d3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6d4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6d5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6d6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6d7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6d8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6d9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6da added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6db added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6dc added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6dd added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6de added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6df added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6e0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6e1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6e2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6e3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6e4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6e5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6e6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6e7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6e8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6e9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6ea added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6eb added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6ec added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6ed added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6ee added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6ef added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6f0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6f1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6f2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6f3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6f4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6f5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6f6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6f7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6f8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6f9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6fa added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6fb added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6fc added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6fd added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6fe added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d6ff added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d700 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d701 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d702 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d703 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d704 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d705 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d706 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d707 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d708 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d709 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d70a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d70b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d70c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d70d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d70e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d70f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d710 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d711 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d712 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d713 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d714 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d715 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d716 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d717 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d718 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d719 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d71a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d71b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d71c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d71d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d71e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d71f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d720 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d721 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d722 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d723 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d724 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d725 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d726 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d727 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d728 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d729 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d72a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d72b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d72c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d72d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d72e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d72f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d730 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d731 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d732 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d733 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d734 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d735 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d736 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d737 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d738 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d739 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d73a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d73b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d73c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d73d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d73e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d73f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d740 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d741 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d742 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d743 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d744 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d745 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d746 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d747 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d748 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d749 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d74a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d74b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d74c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d74d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d74e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d74f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d750 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d751 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d752 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d753 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d754 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d755 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d756 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d757 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d758 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d759 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d75a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d75b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d75c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d75d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d75e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d75f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d760 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d761 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d762 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d763 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d764 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d765 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d766 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d767 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d768 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d769 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d76a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d76b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d76c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d76d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d76e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d76f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d770 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d771 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d772 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d773 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d774 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d775 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d776 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d777 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d778 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d779 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d77a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d77b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d77c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d77d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d77e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d77f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d780 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d781 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d782 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d783 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d784 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d785 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d786 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d787 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d788 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d789 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d78a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d78b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d78c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d78d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d78e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d78f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d790 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d791 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d792 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d793 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d794 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d795 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d796 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d797 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d798 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d799 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d79a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d79b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d79c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d79d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d79e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d79f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7a0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7a1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7a2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7a3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7a4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7a5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7a6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7a7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7a8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7a9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7aa added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7ab added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7ac added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7ad added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7ae added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7af added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7b0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7b1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7b2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7b3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7b4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7b5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7b6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7b7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7b8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7b9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7ba added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7bb added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7bc added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7bd added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7be added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7bf added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7c0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7c1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7c2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7c3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7c4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7c5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7c6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7c7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7c8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7c9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7ca added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7cb added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7cc added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7cd added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7ce added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7cf added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7d0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7d1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7d2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7d3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7d4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7d5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7d6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7d7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7d8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7d9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7da added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7db added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7dc added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7dd added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7de added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7df added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7e0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7e1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7e2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7e3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7e4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7e5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7e6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7e7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7e8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7e9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7ea added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7eb added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7ec added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7ed added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7ee added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7ef added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7f0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7f1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7f2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7f3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7f4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7f5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7f6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7f7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7f8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7f9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7fa added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7fb added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7fc added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7fd added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7fe added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d7ff added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d800 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d801 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d802 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d803 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d804 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d805 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d806 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d807 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d808 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d809 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d80a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d80b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d80c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d80d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d80e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d80f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d810 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d811 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d812 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d813 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d814 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d815 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d816 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d817 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d818 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d819 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d81a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d81b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d81c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d81d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d81e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d81f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d820 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d821 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d822 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d823 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d824 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d825 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d826 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d827 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d828 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d829 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d82a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d82b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d82c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d82d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d82e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d82f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d830 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d831 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d832 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d833 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d834 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d835 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d836 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d837 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d838 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d839 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d83a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d83b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d83c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d83d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d83e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d83f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d840 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d841 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d842 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d843 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d844 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d845 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d846 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d847 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d848 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d849 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d84a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d84b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d84c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d84d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d84e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d84f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d850 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d851 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d852 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d853 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d854 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d855 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d856 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d857 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d858 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d859 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d85a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d85b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d85c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d85d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d85e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d85f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d860 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d861 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d862 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d863 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d864 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d865 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d866 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d867 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d868 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d869 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d86a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d86b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d86c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d86d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d86e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d86f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d870 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d871 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d872 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d873 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1d874 added to Pinecone with embedding.
# ...
# Product with MongoDB ID 676a38ac63fe6ff887c1dbbf added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbc0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbc1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbc2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbc3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbc4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbc5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbc6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbc7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbc8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbc9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbca added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbcb added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbcc added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbcd added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbce added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbcf added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbd0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbd1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbd2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbd3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbd4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbd5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbd6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbd7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbd8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbd9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbda added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbdb added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbdc added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbdd added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbde added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbdf added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbe0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbe1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbe2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbe3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbe4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbe5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbe6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbe7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbe8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbe9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbea added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbeb added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbec added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbed added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbee added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbef added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbf0 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbf1 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbf2 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbf3 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbf4 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbf5 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbf6 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbf7 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbf8 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbf9 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbfa added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbfb added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbfc added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbfd added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbfe added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dbff added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc00 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc01 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc02 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc03 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc04 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc05 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc06 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc07 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc08 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc09 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc0a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc0b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc0c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc0d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc0e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc0f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc10 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc11 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc12 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc13 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc14 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc15 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc16 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc17 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc18 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc19 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc1a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc1b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc1c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc1d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc1e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc1f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc20 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc21 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc22 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc23 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc24 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc25 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc26 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc27 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc28 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc29 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc2a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc2b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc2c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc2d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc2e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc2f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc30 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc31 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc32 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc33 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc34 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc35 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc36 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc37 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc38 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc39 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc3a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc3b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc3c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc3d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc3e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc3f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc40 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc41 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc42 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc43 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc44 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc45 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc46 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc47 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc48 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc49 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc4a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc4b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc4c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc4d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc4e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc4f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc50 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc51 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc52 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc53 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc54 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc55 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc56 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc57 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc58 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc59 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc5a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc5b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc5c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc5d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc5e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc5f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc60 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc61 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc62 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc63 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc64 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc65 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc66 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc67 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc68 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc69 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc6a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc6b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc6c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc6d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc6e added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc6f added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc70 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc71 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc72 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc73 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc74 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc75 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc76 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc77 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc78 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc79 added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc7a added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc7b added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc7c added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc7d added to Pinecone with embedding.
# Product with MongoDB ID 676a38ac63fe6ff887c1dc7e added to Pinecone with embedding.

# %% [markdown]
# ### Setting up the HuggingFace Model
# To provide the LLM, we'll use HuggingFaceHub. HuggingFaceHub is a platform we can connect to and call the model without having to deploy it on our machine. We just define the ID of the model we want to use. In this case, it’s `mistralai/Mixtral-8x7B-Instruct-v0.1`.

# %%
# os.environ["HUGGINGFACE_API_KEY"] = "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"

# repo_id = "mistralai/Mixtral-8x7B-Instruct-v0.1"
# llm = HuggingFaceEndpoint(
#     repo_id=repo_id,
#     temperature=0.8,
#     top_k=50,
#     huggingfacehub_api_token=os.getenv('HUGGINGFACE_API_KEY')
# )

# print(llm("what is capitol of pakistan"))
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to C:\Users\Zainab\.cache\huggingface\token
# Login successful
# C:\Users\Zainab\AppData\Local\Temp\ipykernel_15428\2695682478.py:11: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   print(llm("what is capitol of pakistan"))
# ?
#
# Islamabad is the capital of Pakistan.
#
# Islamabad is the capital of Pakistan. It is a city in the north of the country, between the Margalla Hills and the Rawalpindi District. Islamabad was officially made the capital in 1960, and it is the 10th largest city in Pakistan. It is known for its greenery and beautiful scenery. The city has a population of about 1.5 million people. The official language of Pakistan is Urdu, but many people also speak English. Pakistan is a predominantly Muslim country, and Islam is the official religion. The currency of Pakistan is the Pakistani rupee.

# %%
# retriever = vector_store.as_retriever(
#     search_type="similarity_score_threshold",
#     search_kwargs={"k": 3, "score_threshold": 0.6},
# )

# %% [markdown]
# Ask the LLm about the recommendation about the user query.

# %%
# from langchain import PromptTemplate

# general_template = """
# <Prompt>
#   <Context>
#     You are a virtual shopping assistant for an Ecommerce website which offers different clothing products (like sweatshirts, coats, pants and sneakers, boots etc). Your job is to give stylish personalized recommendation to the user.
#     Focus on keeping a friendly tone and incorporating any item or preference specified by the user in his query. 
#   </Context>
#   <Instructions>
#     - <Focus>Respond only to fashion-related queries. If the user asks a non-fashion question, politely let them know you specialize in fashion and encourage them to ask styling questions.</Focus>
#     - <Tone>Keep the response friendly, helpful, and engaging. Structure your suggestions in a conversational style to make the user feel at ease.</Tone>
#     - <Details>Explain why your suggestions work, considering factors like color coordination, occasion suitability, and style preferences. Ensure the recommendations are practical and fashionable.</Details>
#     - <Examples>Provide clear and concise answers, showcasing your expertise in fashion.</Examples>
#   </Instructions>
#   <Query>
#     <UserQuestion>{question}</UserQuestion>
#   </Query>
#   <Answer>
#     Please provide a concise and to-the-point response.
#   </Answer>
# </Prompt>
# """


# general_prompt = PromptTemplate(
#     template=general_template,
#     input_variables=["question"]
# )

# retriever_template = """

#   You are a chatbot designed to help users with clothing recommendations on an e-commerce website. The website offers tops (e.g., shirts, sweatshirts, dresses), bottoms (e.g., sweatpants, jeans, joggers), and shoes (e.g., boots, sneakers).

#   Answer only clothing-related questions by suggesting how to style specific items (e.g., shirts, pants, dresses, shoes).
#   If the question is general query (not about clothing), no need to give any descriptions or recommendaitons.

#   Examples:

#     - Question: How are you?
#       Answer: I am good, how are you?
      
#     - Question: What to wear with a knee-length slip dress?
#       Answer:
#       Description: Layer a black cropped zipper hoodie over a knee-length slip dress for a chic yet laid-back look. The cropped style balances the dress's silhouette, while the zipper adds a modern edge. Perfect for casual outings or evening strolls.
#       Description: Pair a knee-length slip dress with textured black trousers underneath for a unique layered style. This combination adds structure to the flowy dress, making it suitable for cooler weather or a more formal setting.

#     - Question: How to style a black sweatshirt?
#       Answer:
#       Description: Pair a black high crew tee under a black sweatshirt for a layered casual look. The high crew neckline adds a stylish dimension and makes the outfit cozy for everyday wear.
#       Description: Combine the black sweatshirt with textured black trousers for a refined casual outfit. The trousers’ versatility complements the relaxed vibe of the sweatshirt, making it suitable for casual office wear or a lunch outing.

#     - Question: What shoes go with white jeans?
#       Answer:
#       Description: Pair white jeans with textured black trousers for a bold, layered style. The black trousers peeking through offer a striking contrast and elevate the outfit’s sophistication.
#       Description: Match white jeans with black leather loafers to create a clean and polished look. The loafers' sleek design adds elegance, making the outfit suitable for semi-formal gatherings.

#     - Question: How can I style a red sweater with jeans?
#       Answer:
#       Description: Style a red sweater with textured black trousers instead of jeans for a striking yet polished outfit. The black trousers enhance the boldness of the red while adding a touch of sophistication.
#       Description: Pair the red sweater with a black cropped zipper hoodie layered over it for a trendy and sporty vibe. The cropped fit works well with high-waisted jeans or trousers, creating a balanced silhouette.
     
  
#     When providing recommendations, consider the following:
#   - Color Coordination: Suggest colors that complement or contrast in a flattering way, considering vibrant, neutral, or formal tones.
#   - Fabric Compatibility: Recommend fabric pairings (e.g., cotton with denim, silk blouse with tailored trousers).
#   - Style Matching: Ensure the look matches the intended vibe, whether casual, formal, or sporty.

#   Tailor your response to the needs of the user and take into account if user specifies something in its query (for exmaple, user specifies recommendations for one type of profuct). Respond with a detailed, stylish recommendation alongwith detailed description for the items that are being suggested, ensuring the items match well in terms of color, fabric, of the item inthe query. The output format should be as follows:
  
#   Give 4 suggestions and DO NOT add additional questions or information or examples outside of the recommendation for user query.

#   Question: {question}

#   Answer:

#   """

# retriever_prompt = PromptTemplate(
#     template=retriever_template,
#     input_variables=["question"]
#   )



# response_template = """
#   You are a virtual shopping assistant on an e-commerce platform, specializing in clothing recommendations. The platform offers a wide variety of items including tops (e.g., shirts, sweatshirts, dresses), bottoms (e.g., jeans, joggers, skirts), and shoes (e.g., boots, sneakers, flats).
#   You have been provided with detailed descriptions of relevant products based on the query. Style the product mentioned in the query with the items from these descriptions and try to come up with at least two complete outfits to complete the user’s desired look. For each suggestion:

# - Clearly reference the retrieved product(s) in your response.
# - Show how they complement the product mentioned in the query in terms of color, fabric, and overall vibe.
# - Ensure your response connects back to the query’s intent.
# - Make sure the outfits you come up with are complementary and matches well with eachother
# - Use phrases like "You can pair the [user's item] with our [product]" to personalize the recommendations.
# - If the query does not specify an item, recommend versatile products with clear justifications.
# Personalize your suggestions and structure the response to be friendly, helpful, and engaging. Ensure the suggestions are practical and stylish while explaining why the products match well with the user’s requirements.

# Invite the user to refine their preferences if needed, but *do not add unrelated details or unrelated examples.* DO NOT add more examples or questions to your response. DO not repeat your response, keep it concise and brief it well. 

#     <UserQuestion>{question}</UserQuestion>
#     <Descriptions>{descriptions}</Descriptions>
#     Answer:
    
# """


# response_prompt = PromptTemplate(
#   template=response_template,
#   input_variables=["question", "descriptions"]
# )

# %%
# from typing import List

# def processing(documents):
#     result_dict = {doc["id"]: doc["metadata"]["description"] for doc in documents}
#     return result_dict

# def extract_descriptions(documents: List[Document]) -> str:
#     """
#     Extract and concatenate detailed product descriptions from a list of Document objects.
    
#     Args:
#         documents (List[Document]): List of Document objects from the retriever.

#     Returns:
#         str: A single string containing all concatenated product descriptions.
#     """
#     ids = [doc.id for doc in documents]
#     descriptions = [doc.page_content for doc in documents]
#     # print(descriptions)
#     return "\n\n".join(descriptions)

# %%
# # # Chain 1: Generate initial recommendations (general prompt)
# # # Chain 1: Generate initial recommendations (general prompt)
# # general_chain = (
# #     RunnablePassthrough()                # Pass the user query
# #     | general_prompt                     # Generate initial recommendations
# #     | llm  
# #     | StrOutputParser()                              # Use LLM to produce suggestions
# # )

# # # Chain 2: Enhance with database products (retriever prompt)
# # retriever_chain = (
# #     {
# #         "question": RunnablePassthrough(),          # Pass the user query directly
# #         "recommendations": general_chain            # Take output from general_chain
# #     }
# #     | retriever_prompt                               # Combine recommendations with retrieval
# #     | llm  
# #     | retriever                                         # Use LLM for detailed descriptions
# #     # | extract_descriptions                          # Extract product descriptions
# # )

# # # Chain 3: Final response generation
# # response_chain = (
# #     {
# #         "question": RunnablePassthrough(),          # Pass the user query
# #         "descriptions": retriever_chain             # Take output from retriever_chain
# #     }
# #     | response_prompt                                # Generate final response
# #     | llm                                           # Use LLM for the final output
# #     | StrOutputParser()                             # Parse the output as a string
# # )

# retriever_chain = (
#     {"question": RunnablePassthrough()}
#     | retriever_prompt                               # Combine recommendations with retrieval
#     | llm  
#     | retriever                                         # Use LLM for detailed descriptions
#     # | extract_descriptions 
#     # | StrOutputParser()                        
# )
# response_chain = (
#     {
#         "question": RunnablePassthrough(),          # Pass the user query
#         "descriptions": retriever_chain             # Take output from retriever_chain
#     }
#     | response_prompt                                # Generate final response
#     | llm                                           # Use LLM for the final output
#     | StrOutputParser()                             # Parse the output as a string
# )

# %%
# question = "suggest black clothes?"
# # general = general_chain.invoke({"question": question})
# # print(general)
# retriever = retriever_chain.invoke({"question": question})
# print(retriever)
# # response = response_chain.invoke({"question": question, "descriptions" : retriever})
# # print(response)
# # result = rag_chain2.invoke({"question": question, "descriptions": descriptions})
# # print(result)
# Out:
# [Document(id='7dae5e8b-d6c8-4795-8ec7-48c8c39bfa7d', metadata={'description': 'A black high crew tee for women, ideal for casual wear and versatile styling. It pairs well with jeans, shorts, or skirts for a relaxed look, making it suitable for everyday outings, weekend brunches, or lounging at home. Layer it under a jacket or cardigan for cooler days. Available in sizes SMALL, MEDIUM, LARGE, and X-LARGE, and also offered in IVORY.', 'mongo_id': '67364f096b5f370c97b33e11'}, page_content='A black high crew tee for women, ideal for casual wear and versatile styling. It pairs well with jeans, shorts, or skirts for a relaxed look, making it suitable for everyday outings, weekend brunches, or lounging at home. Layer it under a jacket or cardigan for cooler days. Available in sizes SMALL, MEDIUM, LARGE, and X-LARGE, and also offered in IVORY.'), Document(id='7c45db55-9715-4580-b190-6ebf7b2ba747', metadata={'description': 'A classic black BASIC SWEATSHIRT designed for women, perfect for casual outings and relaxed days. This versatile piece can be easily paired with jeans, leggings, or joggers for a laid-back look. Ideal for layering over a t-shirt or under a jacket, it’s suitable for running errands, lounging at home, or gathering with friends. Available in sizes X-SMALL, SMALL, MEDIUM, LARGE, and X-LARGE, and also comes in TEAL and BURGUNDY for those looking to add a pop of color to their wardrobe.', 'mongo_id': '67364f0f6b5f370c97b33e2f'}, page_content='A classic black BASIC SWEATSHIRT designed for women, perfect for casual outings and relaxed days. This versatile piece can be easily paired with jeans, leggings, or joggers for a laid-back look. Ideal for layering over a t-shirt or under a jacket, it’s suitable for running errands, lounging at home, or gathering with friends. Available in sizes X-SMALL, SMALL, MEDIUM, LARGE, and X-LARGE, and also comes in TEAL and BURGUNDY for those looking to add a pop of color to their wardrobe.'), Document(id='3aa58868-442f-4805-9053-5ef81eba94e8', metadata={'description': 'Classic black suit trousers for men, designed for formal and semi-formal occasions. These trousers can be paired with a matching blazer and a dress shirt for a polished look at business meetings, weddings, or other events that require a smart outfit. They also work well with a more casual button-down shirt for a less formal gathering. Available in a range of sizes from SMALL to XXX-LARGE and also offered in GREY, these trousers provide options to fit various body types and style preferences.', 'mongo_id': '67376e03fd76308feadf7940'}, page_content='Classic black suit trousers for men, designed for formal and semi-formal occasions. These trousers can be paired with a matching blazer and a dress shirt for a polished look at business meetings, weddings, or other events that require a smart outfit. They also work well with a more casual button-down shirt for a less formal gathering. Available in a range of sizes from SMALL to XXX-LARGE and also offered in GREY, these trousers provide options to fit various body types and style preferences.')]

# %%
# #retirveing the most revelant objects form the data base.

# results = vector_store.similarity_search(
#     "wide leg jeans",
#     k=7,
# )
# for res in results:
#     print(f"* {res.page_content} [{res.metadata}]")
# Out:
# *
# CROPPED WIDE LEG PANTS, a WHITE bottoms for women, are available in sizes X-SMALL, SMALL, MEDIUM, LARGE, and X-LARGE. Ideal for casual outings and summer events, these WHITE wide-leg pants match well with crop tops, tank tops, or blouses. Pair them with sandals or sneakers for a comfortable, stylish look. Suitable for various occasions, from weekend gatherings to beach vacations. [{'description': '\nCROPPED WIDE LEG PANTS, a WHITE bottoms for women, are available in sizes X-SMALL, SMALL, MEDIUM, LARGE, and X-LARGE. Ideal for casual outings and summer events, these WHITE wide-leg pants match well with crop tops, tank tops, or blouses. Pair them with sandals or sneakers for a comfortable, stylish look. Suitable for various occasions, from weekend gatherings to beach vacations.', 'mongo_id': '67376da7fd76308feadf78ba'}]
# *  A pair of wide-leg mid-blue jeans for women, designed for a comfortable fit and flattering silhouette. Ideal for casual outings, these jeans can be worn with a fitted top or a loose sweater. Available in sizes 0X-TRUE (2XL), 1X-TRUE (3XL), 2X-TRUE (4XL). [{'description': ' A pair of wide-leg mid-blue jeans for women, designed for a comfortable fit and flattering silhouette. Ideal for casual outings, these jeans can be worn with a fitted top or a loose sweater. Available in sizes 0X-TRUE (2XL), 1X-TRUE (3XL), 2X-TRUE (4XL).', 'mongo_id': '67376dc5fd76308feadf78dc'}]
# *
#
# A pair of black wide-leg pants designed for women, suitable for casual or formal settings. Ideal for pairing with a variety of tops, including blouses or sweaters. The wide-leg design adds a modern touch, while the black color ensures a versatile, elegant appearance. Available in sizes small, medium, large, and x-large. [{'description': '\n\nA pair of black wide-leg pants designed for women, suitable for casual or formal settings. Ideal for pairing with a variety of tops, including blouses or sweaters. The wide-leg design adds a modern touch, while the black color ensures a versatile, elegant appearance. Available in sizes small, medium, large, and x-large.', 'mongo_id': '67376daefd76308feadf78c4'}]
# *
# ALL-DAY WIDE PANTS are bottoms for women, available in light navy, grey, and black colors. Suitable for casual or semi-formal settings, these pants can be paired with blouses or tunics for a stylish yet comfortable look. Available in sizes X-SMALL, SMALL, MEDIUM, LARGE, and X-LARGE. These wide-leg pants offer a versatile option for everyday wear, ideal for work or leisure activities. [{'description': '\nALL-DAY WIDE PANTS are bottoms for women, available in light navy, grey, and black colors. Suitable for casual or semi-formal settings, these pants can be paired with blouses or tunics for a stylish yet comfortable look. Available in sizes X-SMALL, SMALL, MEDIUM, LARGE, and X-LARGE. These wide-leg pants offer a versatile option for everyday wear, ideal for work or leisure activities.', 'mongo_id': '67376db0fd76308feadf78c7'}]
# *  A pair of cropped wide-leg pants for women, available in ivory and black. These pants are suitable for casual outings or informal settings, paired with cropped tops or blouses. The high-waisted design with a straight leg creates a flattering silhouette. Available in sizes small, medium, large, and extra-large. [{'description': ' A pair of cropped wide-leg pants for women, available in ivory and black. These pants are suitable for casual outings or informal settings, paired with cropped tops or blouses. The high-waisted design with a straight leg creates a flattering silhouette. Available in sizes small, medium, large, and extra-large.', 'mongo_id': '67376dc3fd76308feadf78d9'}]
# *  Wide-leg trousers in blue, designed for women. Ideal for casual outings or dressier events, pairing well with simple tops and heels or flats. Available in sizes 0X, 1X, 2X. [{'description': ' Wide-leg trousers in blue, designed for women. Ideal for casual outings or dressier events, pairing well with simple tops and heels or flats. Available in sizes 0X, 1X, 2X.', 'mongo_id': '67376dcdfd76308feadf78e8'}]
# *
#
# Wide-leg trousers for women, available in black and charcoal. Designed for a comfortable fit, they are ideal for casual outings or a polished work look. Pair them with a fitted top and heels for a formal event or a blouse and sneakers for a casual day out. Suitable for work or play, these trousers come in sizes X-Small to X-Large. [{'description': '\n\nWide-leg trousers for women, available in black and charcoal. Designed for a comfortable fit, they are ideal for casual outings or a polished work look. Pair them with a fitted top and heels for a formal event or a blouse and sneakers for a casual day out. Suitable for work or play, these trousers come in sizes X-Small to X-Large.', 'mongo_id': '67376da7fd76308feadf78b9'}]
